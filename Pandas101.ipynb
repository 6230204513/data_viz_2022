# %% [markdown]
# <a href="https://colab.research.google.com/github/6230204513/data_viz_2022/blob/main/Pandas101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #ใช้ pd แทน panda => ใช้ในการจัดการข้อมูลต่างๆ

# %% [markdown]
# .CSV = Comma Separated Value
# ```
# ใช้ comma ในการแยกค่าแต่ละค่า
# ```

# %% [markdown]
# data.go.th

# %%
from google.colab import drive #เชื่อมต่อ google drive กับ Colab ของเรา นี้เป็นคำสั่งเชื่อม |accout colab กับ Drive ควรเป็น accout เดียวกัน|
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os #การจัดการเกี่ยวกับไฟล์ต่าง ๆ มันอยู่โฟลเดอร์ไหน list ออกมาให้ดูหน่อย

# %%
path = '/content/drive/My Drive/dataviz_2021_data' #มันอยู่ใน Driveของเรา บอกทางผ่านไฟล์เรา

# %%
covid_file_path = os.path.join(path,'pm-20-jan-2021.csv')  # ความสำคัญ เราทำบน window linux มันจะไม่เหมือนกัน มันเอาไฟล์มา/กัน กลับมาเขียนต่อ
print(covid_file_path)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-20-jan-2021.csv

# %%
a = path + '/pm-18-jan-2021.csv' 
print(a)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-18-jan-2021.csv

# %% [markdown]
# ##load data to memory

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 10 columns]

# %% [markdown]
# NaN = Not a Number

# %%
data_covid.head(20) # มันจะเอามาเฉพาะหัวตาราง พร้อมกับโชว์ข้อมูลอีก 20 แถว
# Out:
#     No.  ...                                               risk
# 0     1  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 1     2  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2     3  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 3     4  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 4     5  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 5     6  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 6     7  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 7     8  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 8     9  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 9    10  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 10   11  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11   12  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12   13  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 13   14  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# ...

# %%
data_covid.shape #บอกรูปร่างตารางเรา มีกี่ row และกี่ colum
# Out:
# (12653, 10)

# %% [markdown]
# #ชี้ค่าในตาราง

# %% [markdown]
# ##basic

# %%
data_covid['province_of_onset'] #=ชี้ค่าตามตาราง ชี้ที่คอลัมน์
# Out:
# 0        กรุงเทพมหานคร
# 1        กรุงเทพมหานคร
# 2               นครปฐม
# 3        กรุงเทพมหานคร
# 4        กรุงเทพมหานคร
#              ...
# 12648           ชลบุรี
# 12649            ระยอง
# 12650            ระยอง
# 12651            ระยอง
# 12652              ตาก
# Name: province_of_onset, Length: 12653, dtype: object

# %%
data_covid['province_of_onset'][4] #ชี้ที่colummก่อนค่อยชี้ที่row
# Out:
# 'กรุงเทพมหานคร'

# %%
data_covid['risk'][12649]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %% [markdown]
# ##.iloc

# %%
data_covid.iloc[4,7] #หลัก4แถว7
# Out:
# 'กรุงเทพมหานคร'

# %% [markdown]
# ##Table slicing

# %% [markdown]
# ###ตัดมาเฉพาะ columm ที่ต้องการ

# %%
smaller_table = data_covid[['announce_date','province_of_onset','risk']] #เลือกมาเฉพาะคอมละมน์ที่ต้องการ โดยการบอกหัวข้อตาราง
smaller_table
# Out:
#       announce_date  ...                                         risk
# 0         1/12/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         1/17/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         1/22/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         1/22/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         1/24/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...             ...  ...                                          ...
# 12648     1/20/2021  ...                             State Quarantine
# 12649     1/20/2021  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650     1/20/2021  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651     1/20/2021  ...                                Cluster ระยอง
# 12652     1/20/2021  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 3 columns]

# %% [markdown]
# ###ตัดมาเฉพาะ row ที่ต้องการ

# %% [markdown]
# แบบง่าย แต่ใช้การอะไรไม่ค่อยจะได้ (มองเป็น array แล้วตัดแบบ array)

# %%
data_covid.iloc[1:5,:]
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 10 columns]

# %% [markdown]
# ###แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# $pddf$ [list_of_lpgical_value] คือการเลือก row ที่ logical value เป็น True

# %%
data_covid['province_of_onset'] # ใส่ตารางที่ต้องการ[ค่า] ข้อมูลลในคอลัมน์ province_of_onset
# Out:
# 0        กรุงเทพมหานคร
# 1        กรุงเทพมหานคร
# 2               นครปฐม
# 3        กรุงเทพมหานคร
# 4        กรุงเทพมหานคร
#              ...
# 12648           ชลบุรี
# 12649            ระยอง
# 12650            ระยอง
# 12651            ระยอง
# 12652              ตาก
# Name: province_of_onset, Length: 12653, dtype: object

# %%
data_covid['province_of_onset'] =='ขอนแก่น' # columm ไหนเป็น ขอนแก่นจะขึ้น True / columm ที่ไม่ใช่ขอนแก่นจะขึ้น False
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12648    False
# 12649    False
# 12650    False
# 12651    False
# 12652    False
# Name: province_of_onset, Length: 12653, dtype: bool

# %%
data_covid[data_covid['province_of_onset'] =='ขอนแก่น'] #เลือกเฉพาะที่เป็น True = ขอนแก่น
# Out:
#          No.  ...                                           risk
# 180      181  ...                                        สนามมวย
# 462      463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466    1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970    1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637    2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
# 2673    2674  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5948    5949  ...                              Cluster สมุทรสาคร
# 6082    6083  ...                              Cluster สมุทรสาคร
# 9333    9334  ...                           อยู่ระหว่างการสอบสวน
# 9334    9335  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                           อยู่ระหว่างการสอบสวน
# 11697  11698  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %%
data_covid[data_covid['age']>=70] #ตัดมาแค่ช่วงอายุ 'age' ที่ต้องการ '>=70'
# Out:
#          No.  ...                                               risk
# 1          2  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 7          8  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 24        25  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 82        83  ...                                            สนามมวย
# ...      ...  ...                                                ...
# 11694  11695  ...      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 11700  11701  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11730  11731  ...                                  Cluster สมุทรสาคร
# 11741  11742  ...                               อยู่ระหว่างการสอบสวน
# 12102  12103  ...                                  Cluster สมุทรสาคร
#
# [245 rows x 10 columns]

# %% [markdown]
# การชี้ค่าในตารางด้วย data_covid[x] ค่า x สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#   1. ชื่อ column
#   2. ใส่ rows ที่ต้องการ (ใส่ list ที่มีขนาดเท่ากับจำนวนแถว แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (True/False))

# %%
eight_rows_covid = data_covid.iloc[:8,3:] # ตารางตัวอย่าง เลือกมาแค่ 8 Row แรก และ columm 3 เป็นต้นไป
eight_rows_covid
# Out:
#     sex   age  ... district_of_onset                              risk
# 0  หญิง  61.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  หญิง  74.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  หญิง  73.0  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3   ชาย  68.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  หญิง  66.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  หญิง  33.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6  หญิง  57.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 7  หญิง  73.0  ...            หัวหิน  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [8 rows x 7 columns]

# %%
eight_rows_covid[[True,False,True,True,False,True,False,False]]   #2.   ใส่ rows ที่ต้องการ
# Out:
#     sex   age  ... district_of_onset                              risk
# 0  หญิง  61.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  หญิง  73.0  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3   ชาย  68.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  หญิง  33.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 7 columns]

# %%
eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร'  #สร้าง list ของ logical expression
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: province_of_onset, dtype: bool

# %%
eight_rows_covid[eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร']  #เราเอา 2 บรรทัดบนมาบวกกัน
# Out:
#     sex   age  ... district_of_onset                              risk
# 0  หญิง  61.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  หญิง  74.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3   ชาย  68.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  หญิง  66.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  หญิง  33.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6  หญิง  57.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [6 rows x 7 columns]

# %%
eight_rows_covid['district_of_onset'] == 'เมือง'
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: district_of_onset, dtype: bool

# %% [markdown]
# # .isnull() ใช้ตรวจสอบว่าเป็นค่าว่าง (NaN) หรือไม่

# %%
eight_rows_covid['district_of_onset'].isnull() #NaN เป็นค่าว่าง จึงไม่สามารถใช้ =='NaN' ได้ และใช้คำสั่ง isnull() คือเลือกค่าว่าง
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: district_of_onset, dtype: bool

# %% [markdown]
# # Quiz
#  (ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
#   1. คำนวณ อายุเฉลี่ย ของผู้ชาย ในข้อมูลทั้งหมด
#   2. คำนวณ อายุเฉลี่ย ของผู้ชาย ในจังหวัดขอนแก่น
#   3. หาจำนวนผู้ป่วยที่เป็นคน "ที่ไม่ใช่คนไทย"

# %% [markdown]
#   1. คำนวณ อายุเฉลี่ย ของผู้ชาย ในข้อมูลทั้งหมด

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
male = this_data[this_data['sex']=='ชาย']
male['age']
# Out:
# 3        68.0
# 8        63.0
# 10       33.0
# 11       61.0
# 12        6.0
#          ...
# 12640    66.0
# 12641    29.0
# 12643    39.0
# 12646    18.0
# 12647    42.0
# Name: age, Length: 4819, dtype: float64

# %%
sum = 0 #กำหนด sum เป็น 0 เผื่อใช้รวมผลลัพธ์ใน loop |ตัวแปร sum จะมารับค่าทั้งหมด  ถ้าเริ่มที่1 คือเอาตัวแปรมาคูณกัน
N = 0 #กำหนด N เป็น 0 เพื่อใช้นับจำนวนผลลัพธ์ใน loop 
for a in male['age']: # ให้ a วนloop ในตาราง male ที่ คอมลัน์ age
    
    if a > 0: # ถ้ามันมากกว่า 0 แสดงว่าเป็นอายุคนปกติ ถ้า a เป็นอย่างอื่น ทำให้เกิดค่าผิดพลาด
        sum += a #ให้ a บวกเพิ่มเข้าไปใน sum หรือ sum = sum + a  ผลรวมอายุทั้งหมด
        N += 1 # ให้ N บวกเพิ่มขึ้นทีละ 1 |N บวกเพิ่มทีละ1  จำนวนคนทั้งหมด

print(f'อายุเฉลี่ย ของ ผู้ป่วยชาย {sum/N}') #แสดงผลลัพธ์ที่เป็นค่าเฉลี่ยของ sum/N
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยชาย 39.46076940331987

# %% [markdown]
#   2. คำนวณ อายุเฉลี่ย ของผู้ชาย ในจังหวัดขอนแก่น

# %%
male_KK = male[male['province_of_onset']=='ขอนแก่น'] #กำหนดตัวแปร male_KK ให้เลือกตาราง male ที่คอลัมน์ provint_of_onset เป็นขอนแก่นเท่านั้น

sum = 0 #กำหนด sum เป็น 0 เผื่อใช้รวมผลลัพธ์ใน loop
N = 0 #กำหนด N เป็น 0 เพื่อใช้นับจำนวนผลลัพธ์ใน loop 
for a in male_KK['age']:   # ให้ a วนloop ในตาราง male_KK ที่ คอมลัน์ age
    
    if a > 0: # ถ้ามันมากกว่า 0 แสดงว่าเป็นอายุคนปกติ
        sum += a # sum = sum + m |ให้ a บวกเพิ่มเข้าไปใน sum
        N += 1 # ให้ N บวกเพิ่มขึ้นทีละ 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยชาย ในจังหวัดขอนแก่น {sum/N}') #แสดงผลลัพธ์ที่เป็นค่าเฉลี่ยของ sum/N
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยชาย ในจังหวัดขอนแก่น 26.571428571428573

# %% [markdown]
#   3. หาจำนวนผู้ป่วยที่เป็นคน "ที่ไม่ใช่คนไทย"

# %%
this_data_3 = data_covid[['sex','age','nationality']] #กำหนดให้ this_data_3 แสดงตาราง ค่า 'sex','age','nationality'

# %%
this_data_3 # แสดง this_data_3 ออกมา โดยตารางต้องประกอบไปด้วย sex age nationality
# Out:
#         sex   age nationality
# 0      หญิง  61.0       China
# 1      หญิง  74.0       China
# 2      หญิง  73.0    Thailand
# 3       ชาย  68.0       China
# 4      หญิง  66.0       China
# ...     ...   ...         ...
# 12648  หญิง  44.0    Thailand
# 12649  หญิง  52.0    Thailand
# 12650  หญิง  23.0    Thailand
# 12651  หญิง  29.0    Thailand
# 12652  หญิง  22.0       Burma
#
# [12653 rows x 3 columns]

# %%
outTH = this_data_3[this_data_3['nationality']!='Thailand'] #กำหนดให้ outTH แสดงค่าที่ไม่ใช่ Thailand โดยใช้คำสั่ง "!=" 
outTH['nationality']
# Out:
# 0           China
# 1           China
# 3           China
# 4           China
# 5           China
#            ...
# 12614       Burma
# 12615       Burma
# 12617     Ireland
# 12618    Pakistan
# 12652       Burma
# Name: nationality, Length: 5340, dtype: object

# %%
outTH.count() # ใช้ count() ตัดค่า Missing ออก
# Out:
# sex            2889
# age            2038
# nationality    4129
# dtype: int64

# %% [markdown]
# แสดงอีก 1 วิธี

# %%
this_data_4 = data_covid[['sex','age','nationality']]

# %%
this_data_4
# Out:
#         sex   age nationality
# 0      หญิง  61.0       China
# 1      หญิง  74.0       China
# 2      หญิง  73.0    Thailand
# 3       ชาย  68.0       China
# 4      หญิง  66.0       China
# ...     ...   ...         ...
# 12648  หญิง  44.0    Thailand
# 12649  หญิง  52.0    Thailand
# 12650  หญิง  23.0    Thailand
# 12651  หญิง  29.0    Thailand
# 12652  หญิง  22.0       Burma
#
# [12653 rows x 3 columns]

# %%
 this_data_4['nationality']!='Thailand'
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 12648    False
# 12649    False
# 12650    False
# 12651    False
# 12652     True
# Name: nationality, Length: 12653, dtype: bool

# %%
sum( this_data_4['nationality']!='Thailand') # sum ทั้งหมดที่ไม่ใช่ Thailand
# Out:
# 5340

# %%
sum( this_data_4['nationality'].dropna()!='Thailand') # ใช้ dropna() เพื่อตัดค่า Missing ออก
# Out:
# 4129

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ Record (dropna)

# %% [markdown]
# missing = None NA(not autorized) NaN (not a number)

# %%
this_data.shape #(12423, 3)
# Out:
# (12653, 3)

# %%
print(data_covid.shape)
print(data_covid.dropna().shape)
# Out:
# (12653, 10)
# (6655, 10)

# %%
this_data.dropna()
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8478 rows x 3 columns]

# %%
print(this_data.dropna().shape)
print(this_data.dropna(subset=['sex','age']).shape)
# Out:
# (8478, 3)
# (8880, 3)

# %% [markdown]
# # ตรวจสอบ Missing (isnull())

# %%
this_data.isnull()
# Out:
#          sex    age  province_of_onset
# 0      False  False              False
# 1      False  False              False
# 2      False  False              False
# 3      False  False              False
# 4      False  False              False
# ...      ...    ...                ...
# 12648  False  False              False
# 12649  False  False              False
# 12650  False  False              False
# 12651  False  False              False
# 12652  False  False              False
#
# [12653 rows x 3 columns]

# %%
this_data.isnull().any() # .any() นำเอาค่าความจริงในคอลัมน์ มา or กัน
# Out:
# sex                  True
# age                  True
# province_of_onset    True
# dtype: bool

# %%
this_data.isnull().all() # .all() นำเอาค่าความจริงในคอลัมน์ มา And กัน
# Out:
# sex                  False
# age                  False
# province_of_onset    False
# dtype: bool

# %%
this_data.isnull().any().any() # มี True หมายความว่ามีค่าว่างอยู่
# Out:
# True

# %%
this_data.dropna(subset=['sex', 'age']).isnull().any
# Out:
# <bound method DataFrame.any of          sex    age  province_of_onset
# 0      False  False              False
# 1      False  False              False
# 2      False  False              False
# 3      False  False              False
# 4      False  False              False
# ...      ...    ...                ...
# 12648  False  False              False
# 12649  False  False              False
# 12650  False  False              False
# 12651  False  False              False
# 12652  False  False              False
#
# [8880 rows x 3 columns]>

# %%
this_data.dropna(subset=['sex', 'age'])
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8880 rows x 3 columns]

# %% [markdown]
# ###1 เพื่อให้ได้ผลลัพธ์การจัดการ dropna ต้องเอาตัวแปรมารับ

# %%
this_data_nonull = this_data.dropna(subset=['sex', 'age'])

# %%
this_data_nonull.isnull().any()
# Out:
# sex                  False
# age                  False
# province_of_onset     True
# dtype: bool

# %% [markdown]
# ### 2. Update ตารางด้วยตัวแปร inplace

# %%
this_data.dropna(subset=['sex','age'],inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
this_data.isnull().any()
# Out:
# sex                  False
# age                  False
# province_of_onset     True
# dtype: bool

# %%
aa = this_data.dropna(subset=['sex','age'],inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
aa

# %% [markdown]
# ### แทนค่า Missing ที่เหมาะสม (fillna())

# %%
this_data = data_covid[['sex','age','province_of_onset']]
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
print(f'จำนวน record ก่อน drop missing ใน province {this_data.shape[0]}')
print(f'จำนวน record หลัง drop missing ใน province {this_data.dropna(subset=["province_of_onset"]).shape[0]}')
# Out:
# จำนวน record ก่อน drop missing ใน province 12653
# จำนวน record หลัง drop missing ใน province 10662

# %% [markdown]
# ### แทนด้วย class ใหม่

# %%
this_data_updated = this_data.fillna(value={'sex':'ไม่รู้', 'age':-99, 'province_of_onset':'ไม่รู้'})
this_data_updated.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
this_data_updated.tail(15) # ดูค่า 15 ค่า จากท้ายสุด Missing แทนค่าด้วย -99
# Out:
#           sex   age province_of_onset
# 12638  ไม่รู้ -99.0         สมุทรสาคร
# 12639  ไม่รู้ -99.0         สมุทรสาคร
# 12640     ชาย  66.0   พระนครศรีอยุธยา
# 12641     ชาย  29.0          ปทุมธานี
# 12642    หญิง  50.0           ราชบุรี
# 12643     ชาย  39.0              สตูล
# 12644    หญิง  49.0       สมุทรปราการ
# 12645    หญิง  44.0            ชลบุรี
# 12646     ชาย  18.0       สมุทรปราการ
# 12647     ชาย  42.0     กรุงเทพมหานคร
# 12648    หญิง  44.0            ชลบุรี
# 12649    หญิง  52.0             ระยอง
# 12650    หญิง  23.0             ระยอง
# 12651    หญิง  29.0             ระยอง
# 12652    หญิง  22.0               ตาก

# %%
this_data_updated.isnull().any()
# Out:
# sex                  False
# age                  False
# province_of_onset    False
# dtype: bool

# %% [markdown]
# ### 2. แทนด้วยค่าที่เหมาะสม
# - ตามใจคนทำ
# - ค่ากลาง

# %% [markdown]
# ตามใจคนทำ

# %%
data_covid.head()
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
data_covid_fillasiwant = data_covid.fillna(value={'sex':'หญิง'}) # เรามีข้อมูลว่า เพศหญิง มีเยอะกว่าเพศชาย ดังนั้นจึงเลือกแทนค่า Missing ด้วยเพศหญิง

# %%
data_covid_fillasiwant.isnull().any()
# Out:
# No.                      False
# announce_date            False
# notification_date         True
# sex                      False
# age                       True
# nationality               True
# province_of_isolation     True
# province_of_onset         True
# district_of_onset         True
# risk                      True
# dtype: bool

# %% [markdown]
# แทนด้วยค่ากลาง

# %%
data_covid['age']
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 3        68.0
# 4        66.0
#          ...
# 12648    44.0
# 12649    52.0
# 12650    23.0
# 12651    29.0
# 12652    22.0
# Name: age, Length: 12653, dtype: float64

# %%
data_covid['age'].mean() #คำสั่งนี้ไม่นำค่า Missing มาคำนวณด้วยอยู่แล้ว
# Out:
# 38.054748339151

# %%
data_covid_fillwithmean = data_covid.fillna(value={'age': data_covid['age'].mean()})

# %%
data_covid_fillwithmean.isnull().any()
# Out:
# No.                      False
# announce_date            False
# notification_date         True
# sex                       True
# age                      False
# nationality               True
# province_of_isolation     True
# province_of_onset         True
# district_of_onset         True
# risk                      True
# dtype: bool

# %% [markdown]
# ### การวนลูป record ในตาราง (.iterrows)

# %%
this_data = data_covid[['sex','age','province_of_onset']]
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
for each_row in this_data.iterrows(): # print 5 row
  #print(each_row) 
  #print(each_row[1])
    if (each_row[1]['age']==20) and (each_row[1]['province_of_onset'] == 'ขอนแก่น') : # print เฉพาะ age = 20 and province_of_onset = ขอนแก่น
        print(each_row)
# Out:
# (9334, sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object)

# %%
for each_row in this_data.iterrows() :
  #print(each_row) 
  #print(each_row[1]) 
  #print(each_row['sex'])
    if (each_row[1]['age']<=20) and (each_row[1]['province_of_onset'] == 'ขอนแก่น') : # print เฉพาะ age <= 20 and province_of_onset = ขอนแก่น
        print(each_row)
# Out:
# (1466, sex                      ชาย
# age                       19
# province_of_onset    ขอนแก่น
# Name: 1466, dtype: object)
# (9333, sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 9333, dtype: object)
# (9334, sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object)
# (10610, sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 10610, dtype: object)
# (11517, sex                      ชาย
# age                       12
# province_of_onset    ขอนแก่น
# Name: 11517, dtype: object)
# (11697, sex                     หญิง
# age                       17
# province_of_onset    ขอนแก่น
# Name: 11697, dtype: object)

# %% [markdown]
# ###การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array (.iloc)

# %%
for each_row in range(this_data.shape[0]):
    if (this_data.iloc[each_row,1] <= 20) and (this_data.iloc[each_row,2] == 'ขอนแก่น'):  #each_row คือ ตัวเลข
        print(each_row)
        print(this_data.iloc[each_row,:])
# Out:
# 1466
# sex                      ชาย
# age                       19
# province_of_onset    ขอนแก่น
# Name: 1466, dtype: object
# 9333
# sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 9333, dtype: object
# 9334
# sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object
# 10610
# sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 10610, dtype: object
# 11517
# sex                      ชาย
# age                       12
# province_of_onset    ขอนแก่น
# Name: 11517, dtype: object
# 11697
# sex                     หญิง
# age                       17
# province_of_onset    ขอนแก่น
# Name: 11697, dtype: object

# %% [markdown]
# ##Quiz ตัดตารางออกมาเฉพาะปี 2021 announce_date ในปี 2021

# %% [markdown]
# Hint
#
# - วนลูปหา index ของปี 2021
# - ตัดตารางมาเฉพาะ ปี 2021

# %%
TF=list()
for each_row in data_covid.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2021':
        TF.append(True)
    else:
        TF.append(False)

data_covid[TF].head()
# Out:
#        No.  ...                                               risk
# 6884  6885  ...                                  Cluster สมุทรสาคร
# 6885  6886  ...                                      Cluster ระยอง
# 6886  6887  ...                                        สถานบันเทิง
# 6887  6888  ...                                  Cluster สมุทรสาคร
# 6888  6889  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
#
# [5 rows x 10 columns]

# %% [markdown]
# #HW กลุ่ม 2 || เลือกข้อมูลมาเฉพาะวัน announce_date เป็นวันที่ 1-20

# %%
AD = list() #สร้าง list ว่าง และกำหนดให้มีชื่อว่า AD เพื่อใช้เติมค่า loop
for each_row in data_covid.iterrows():  # วน loop แต่ละแถว ใน data_covid
    if each_row[1]['announce_date'].split('/')[1] <= '20' : #สร้างเงื่อนไข เลือกวันที่ของ announce_date ที่ <= 20 แยกตัวเลข โดยใช้ / จากนั้นเลือกสมาชิกตัวที่ 1 [1] เนื่องจาก list จะเริ่มนับสมาชิกจาก 0 
        AD.append(True) #ค่าใดที่ตรวจสอบแล้วตรงตามเงื่อนไข(เป็นจริง) ให้ใส่ลงไปใน List โดยหารใช้คำสั่ง .append()
    else:
        AD.append(False) #ค่าใดที่ตรวจสอบแล้วไม่ตรงตามเงื่อนไข(ไม่เป็นจริง) จะไม่ถูกใส่ลงไปใน List 

data_covid[AD] # แสดงผลลัพธ์ทั้งหมดที่ตรงตามเงื่อนไขก่อนหน้า
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 32        33  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 33        34  ...              บุคลากรด้านการแพทย์และสาธารณสุข
# 34        35  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5135 rows x 10 columns]

# %%
AD = list() #กำหนด AD ให้เป็น list ว่าง เพื่อใช้เติมค่า loop
for each_row in data_covid.iterrows():  # loop แต่ละแถว ใน data_covid
    if (int(each_row[1]['announce_date'].split('/')[1] <= '20') and (int(each_row[1]['announce_date'].split('/')[1])>=1) ): #สร้างเงื่อนไข แยกตัวเลข โดยใช้ /  เลือกตัวเลขที่เป็นสมาชิกตัวที่1 [1] (เนื่องจาก list จะเริ่มนับสมาชิกจาก 0) ของ announce_date ที่ <= 20 และ >=1 
       AD.append(True) #ค่าใดที่ตรวจสอบแล้วตรงตามเงื่อนไข(เป็นจริง) ให้ใส่ลงไปใน List โดยหารใช้คำสั่ง .append()
    else:
        AD.append(False) #ค่าใดที่ตรวจสอบแล้วไม่ตรงตามเงื่อนไข(ไม่เป็นจริง) จะไม่ถูกใส่ลงไปใน List 

data_covid[AD] # แสดงผลลัพธ์ทั้งหมดที่ตรงตามเงื่อนไขก่อนหน้า
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 32        33  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 33        34  ...              บุคลากรด้านการแพทย์และสาธารณสุข
# 34        35  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5135 rows x 10 columns]

# %% [markdown]
# #Function ตัวช่วยใน pandas

# %% [markdown]
# .describe() คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
data_covid.describe()
# Out:
#                 No.          age
# count  12653.000000  8881.000000
# mean    6327.000000    38.054748
# std     3652.750813    15.125178
# min        1.000000     0.100000
# 25%     3164.000000    27.000000
# 50%     6327.000000    36.000000
# 75%     9490.000000    48.000000
# max    12653.000000    97.000000

# %% [markdown]
# .mean() คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
data_covid[data_covid['sex']=='ชาย']['age'].mean()
# Out:
# 39.46076940331987

# %% [markdown]
# .isnull()

# %%
data_covid.isnull
# Out:
# <bound method DataFrame.isnull of          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 10 columns]>
