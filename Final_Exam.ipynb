# %% [markdown]
# <a href="https://colab.research.google.com/github/6230204513/data_viz_2022/blob/main/Final_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ข้อสอบปลาย

# %% [markdown]
# ##ก่อนเริ่ม : การเตรียมข้อมูล

# %% [markdown]
# ###นำเข้าข้อมูล

# %% [markdown]
# เริ่มแรกเราจะใช้ Import pandas สำหรับใช้อ่านข้อมูลและอื่นส่วน Import os เป็นคำสั่งสำหรับอ่านค่าเพื่อให้ดึงข้อมูลมาจากไดร์ฟ

# %%
import pandas as pd
import os

# %% [markdown]
# ดึงข้อมูลโดยใช้ path เป็นตัวรองรับจาก Drive ที่ชื่อ ovrdt_data

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/ovrdt_data'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# จากนั้นดึงข้อมูลตารางจากไฟล์ที่ชื่อ alldb.csv และ hospital_list.xlsx จากได้ drive ด้วยคำสั่่ง os.path.join และ อ่านค่าด้วย pd.read_csv พร้อมใช้ตัวแปรรองรับเป็น data_mid

# %%
data_file_path1 = os.path.join(path,'alldb.csv') 
alldb = pd.read_csv(data_file_path1)
alldb #ตารางแสดงการอ่านจากไฟล์ alldb.csv
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# ...

# %%
alldb.isnull().sum()
# Out:
# Unnamed: 0          0
# user              762
# RowKey              1
# care            39963
# date              554
# ov                364
# phone               3
# site               99
# time              557
# urine             253
# pid             39890
# PartitionKey      185
# title             444
# age               542
# dtype: int64

# %%
data_new_alldb = alldb[['user','RowKey','date','phone','site','time','urine','ov','PartitionKey']]
data_new_alldb
# Out:
#                 user                                    RowKey        date  \
# 0               test                                       NaN         NaN
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png         NaN
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  2022-02-23
# ...              ...                                       ...         ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C         NaN
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1         NaN
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9         NaN
# 40033            NaN                            bbuogxulur.png         NaN
# 40034            NaN                            zttpqogiso.png         NaN
#
#                   phone   site      time            urine   ov  \
# ...

# %%
data_new_alldb.isnull().sum()
# Out:
# user            762
# RowKey            1
# date            554
# phone             3
# site             99
# time            557
# urine           253
# ov              364
# PartitionKey    185
# dtype: int64

# %%
dn_alldb_drop = data_new_alldb.dropna()
dn_alldb_drop #ใช้ตารางนี้ได้เลย
# Out:
#          user                                RowKey        date  \
# 185     85879                        shmpdrmtgc.png  2022-03-24
# 186    45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23
# 187    45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23
# 188     27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 190     06223                        kfpwuaqldj.png  2022-03-23
# ...       ...                                   ...         ...
# 40013   ttest                        crqcufokmn.png  2022-02-21
# 40014   ttest                        gzxgflnowr.png  2022-02-21
# 40016     xxx                        jytlopevha.png  2022-02-17
# 40022     yyy                        ivccsksowb.png  2022-02-17
# 40023     zzz                        psudrnccsh.png  2022-02-17
#
#                    phone   site      time            urine ov PartitionKey
# 185         OPPO CPH2293  05194  13:08:39          มีตะกอน  0         0000
# ...

# %%
removes = data_new_alldb.shape[0] - dn_alldb_drop.shape[0]
print(f'size before drop = {data_new_alldb.shape[0]}')
print(f'size after drop = {dn_alldb_drop.shape[0]}')
print(f'% from drop = {(removes/data_new_alldb.shape[0])*100}')
# Out:
# size before drop = 40035
# size after drop = 38663
# % from drop = 3.427001373797927

# %%
set(dn_alldb_drop['site'])
# Out:
# {' 0502',
#  '00004',
#  '00006',
#  '00007',
#  '00008',
#  '00012',
#  '00016',
#  '00017',
#  '00018',
#  '00027',
#  '00028',
#  '00040',
#  '00052',
#  '00055',
#  '00061',
#  '00069',
#  '00070',
#  '00071',
#  '00081',
#  '00082',
#  '00090',
#  '00094',
#  '00096',
#  '00108',
#  '00109',
#  '00115',
#  '00120',
#  '00122',
#  '00127',
#  '00163',
#  '00164',
#  '00165',
#  '00166',
#  '00169',
#  '00170',
#  '00171',
#  '00173',
#  '00174',
#  '00176',
#  '00177',
#  '00178',
#  '00179',
#  '00180',
#  '00182',
#  '00185',
#  '00186',
#  '00187',
#  '00189',
#  '00190',
#  '00191',
#  '00192',
#  '00193',
#  '00194',
#  '00195',
#  '00196',
#  '00197',
#  '00198',
#  '00200',
#  '00202',
#  '00204',
#  '00205',
#  '00206',
#  '00207',
#  '00209',
#  '00213',
#  '00214',
#  '00217',
#  '00218',
#  '00219',
#  '00229',
#  '00232',
#  '00235',
#  '00240',
#  '00247',
#  '00266',
#  '00271',
#  '00279',
#  '00323',
#  '00331',
#  '00333',
#  '00346',
#  '00348',
#  '00381',
# ...

# %%
dn_alldb_drop['site'].replace({' 0502':'ไม่ระบุ',
                            '05087\n':'05087',
                            '05250\n':'05250',
                            '05350ยอ':'05350',
                            '11111111':'11111',
                            '13777t':'13777',
                            '13943\n\n':'13943',
                            '5271':'ไม่ระบุ',
                            'aaa':'ไม่ระบุ',
                            'bbb':'ไม่ระบุ',
                            'ccc':'ไม่ระบุ',
                            'eee':'ไม่ระบุ',
                            'fff':'ไม่ระบุ',
                            'ggg':'ไม่ระบุ',
                            'hhh':'ไม่ระบุ',
                            'iii':'ไม่ระบุ',
                            'jjj':'ไม่ระบุ',
                            'kkk':'ไม่ระบุ',
                            'lll':'ไม่ระบุ',
                            'mmm':'ไม่ระบุ',
                            'ppp':'ไม่ระบุ',
                            'qqq':'ไม่ระบุ',
                            'rrr':'ไม่ระบุ',
                            'sss':'ไม่ระบุ',
                            'test':'ไม่ระบุ',
                            'ttt':'ไม่ระบุ',
                            'uuu':'ไม่ระบุ',
                            'vvv':'ไม่ระบุ',
                            'www':'ไม่ระบุ',
                            'xxx':'ไม่ระบุ',
                            'yyy':'ไม่ระบุ',
                            'zzz':'ไม่ระบุ',
                            '043.1':'ไม่ระบุ'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
set(dn_alldb_drop['site'])
# Out:
# {'00004',
#  '00006',
#  '00007',
#  '00008',
#  '00012',
#  '00016',
#  '00017',
#  '00018',
#  '00027',
#  '00028',
#  '00040',
#  '00052',
#  '00055',
#  '00061',
#  '00069',
#  '00070',
#  '00071',
#  '00081',
#  '00082',
#  '00090',
#  '00094',
#  '00096',
#  '00108',
#  '00109',
#  '00115',
#  '00120',
#  '00122',
#  '00127',
#  '00163',
#  '00164',
#  '00165',
#  '00166',
#  '00169',
#  '00170',
#  '00171',
#  '00173',
#  '00174',
#  '00176',
#  '00177',
#  '00178',
#  '00179',
#  '00180',
#  '00182',
#  '00185',
#  '00186',
#  '00187',
#  '00189',
#  '00190',
#  '00191',
#  '00192',
#  '00193',
#  '00194',
#  '00195',
#  '00196',
#  '00197',
#  '00198',
#  '00200',
#  '00202',
#  '00204',
#  '00205',
#  '00206',
#  '00207',
#  '00209',
#  '00213',
#  '00214',
#  '00217',
#  '00218',
#  '00219',
#  '00229',
#  '00232',
#  '00235',
#  '00240',
#  '00247',
#  '00266',
#  '00271',
#  '00279',
#  '00323',
#  '00331',
#  '00333',
#  '00346',
#  '00348',
#  '00381',
#  '00382',
# ...

# %%
data_file_path2 = os.path.join(path,'hospital_list.xlsx') 
hospital_list = pd.read_excel(data_file_path2)
hospital_list #ตารางแสดงการอ่านจากไฟล์ hospital_list.xlsx
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
# ...

# %%
hospital_list.isnull().sum()
# Out:
# hcode               0
# name                1
# zone_code           0
# zone_name           4
# provincecode        1
# province            0
# amphurcode          2
# amphur              2
# tamboncode        168
# tambon            209
# code4               1
# name5               3
# code9            5294
# name10           5294
# short_thai          6
# short_english       6
# dtype: int64

# %%
new_hospital = hospital_list[['hcode',	'name',	'zone_code',	'zone_name',	'provincecode',	'province',	'amphurcode',	'amphur',	'tamboncode',	'tambon']]
new_hospital
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
# ...

# %%
new_hospital.isnull().sum()
# Out:
# hcode             0
# name              1
# zone_code         0
# zone_name         4
# provincecode      1
# province          0
# amphurcode        2
# amphur            2
# tamboncode      168
# tambon          209
# dtype: int64

# %%
dn_hospital_drop = new_hospital.dropna()
dn_hospital_drop
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
# ...

# %%
dn_hospital_drop.isnull().sum()
# Out:
# hcode           0
# name            0
# zone_code       0
# zone_name       0
# provincecode    0
# province        0
# amphurcode      0
# amphur          0
# tamboncode      0
# tambon          0
# dtype: int64

# %%
removes = new_hospital.shape[0] - dn_hospital_drop.shape[0]
print(f'size before drop = {data_new_alldb.shape[0]}')
print(f'size after drop = {new_hospital.shape[0]}')
print(f'% from drop = {(removes/new_hospital.shape[0])*100}')
# Out:
# size before drop = 40035
# size after drop = 17103
# % from drop = 1.245395544641291

# %%
set(dn_hospital_drop['hcode'])
# Out:
# {'05994',
#  '10006',
#  '17429',
#  '21336',
#  '02624',
#  '24321',
#  '14434',
#  '03812',
#  '03974',
#  '07933',
#  '08586',
#  '24624',
#  '08316',
#  '06975',
#  '01439',
#  '03863',
#  '14066',
#  '10117',
#  '03442',
#  '04147',
#  '00779',
#  '04613',
#  '14697',
#  '07429',
#  '09040',
#  '04014',
#  '09538',
#  '25909',
#  '00266',
#  '03878',
#  '07861',
#  '08165',
#  '10863',
#  '05653',
#  '03721',
#  '12284',
#  '05722',
#  '01232',
#  '04302',
#  '07762',
#  '10155',
#  '00332',
#  '27015',
#  '01920',
#  '05223',
#  '06367',
#  '24951',
#  '26634',
#  '09751',
#  '99860',
#  '07114',
#  '15132',
#  '15200',
#  '05293',
#  '06071',
#  '14145',
#  '06173',
#  '07277',
#  '14286',
#  '04753',
#  '00021',
#  '01172',
#  '05259',
#  '05342',
#  '09118',
#  '02752',
#  '10178',
#  '00567',
#  '27340',
#  '07522',
#  '09448',
#  '06386',
#  '25775',
#  '02484',
#  '05265',
#  '09400',
#  '06338',
#  '07794',
#  '01322',
#  '06979',
#  '22524',
#  '04459',
#  '02749',
# ...

# %%
data = dn_alldb_drop.merge(dn_hospital_drop,how='left',left_on='site',right_on='hcode')
data
# Out:
#          user                                RowKey        date  \
# 0       85879                        shmpdrmtgc.png  2022-03-24
# 1      45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23
# 2      45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23
# 3       27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 4       06223                        kfpwuaqldj.png  2022-03-23
# ...       ...                                   ...         ...
# 38658   ttest                        crqcufokmn.png  2022-02-21
# 38659   ttest                        gzxgflnowr.png  2022-02-21
# 38660     xxx                        jytlopevha.png  2022-02-17
# 38661     yyy                        ivccsksowb.png  2022-02-17
# 38662     zzz                        psudrnccsh.png  2022-02-17
#
#                    phone     site      time            urine ov PartitionKey  \
# 0           OPPO CPH2293    05194  13:08:39          มีตะกอน  0         0000
# ...

# %%
data.isnull().sum()
# Out:
# user              0
# RowKey            0
# date              0
# phone             0
# site              0
# time              0
# urine             0
# ov                0
# PartitionKey      0
# hcode           379
# name            379
# zone_code       379
# zone_name       379
# provincecode    379
# province        379
# amphurcode      379
# amphur          379
# tamboncode      379
# tambon          379
# dtype: int64

# %%
drop_data = data.dropna()
drop_data
# Out:
#          user                                RowKey        date  \
# 0       85879                        shmpdrmtgc.png  2022-03-24
# 1      45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23
# 2      45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23
# 3       27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 4       06223                        kfpwuaqldj.png  2022-03-23
# ...       ...                                   ...         ...
# 38562   76331                        pvpiawlexb.png  2022-02-23
# 38565   68317                        rtutxrlbam.png  2022-02-23
# 38566   68317                        dmuragqwza.png  2022-02-23
# 38569   68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663  2022-03-24
# 38570   99771  E04D3D60-B916-40A1-AE77-91CCD89DD084  2022-03-31
#
#                    phone   site      time            urine ov PartitionKey  \
# 0           OPPO CPH2293  05194  13:08:39          มีตะกอน  0         0000
# ...

# %%
removes = data.shape[0] - drop_data.shape[0]
print(f'size before drop = {data.shape[0]}')
print(f'size after drop = {drop_data.shape[0]}')
print(f'% from drop = {(removes/data.shape[0])*100}')
# Out:
# size before drop = 38663
# size after drop = 38284
# % from drop = 0.980265369991982

# %%
set(drop_data['user'])
# Out:
# {'92042',
#  '19903',
#  '50349',
#  '00131',
#  '75921',
#  '48768',
#  '00266',
#  '19364',
#  '73233',
#  '23675',
#  '46627',
#  '00253',
#  '96699',
#  '18873',
#  '78257',
#  '00001',
#  '52013',
#  '46948',
#  '27604',
#  '71112',
#  '38614',
#  '17415',
#  '71970',
#  '00021',
#  '45783',
#  '53356',
#  '43868',
#  '21860',
#  '02639',
#  '81065',
#  '55300',
#  '72988',
#  '70610',
#  '58271',
#  '84375',
#  '75771',
#  '19201',
#  '03080',
#  '5600190011969',
#  '00206',
#  '19578',
#  '66261',
#  '74369',
#  '98126',
#  '58845',
#  '24563',
#  '00017',
#  '3460500500020',
#  '61320',
#  '18890',
#  '00267',
#  '70948',
#  '70940',
#  '49863',
#  '34988',
#  '00183',
#  '47567',
#  '05961',
#  '48514',
#  '78731',
#  '28961',
#  '00074',
#  '55365',
#  '24179',
#  '00150',
#  '29159',
#  '48298',
#  '77576',
#  '12966',
#  '35605',
#  '56845',
#  '54599',
#  '00036',
#  '96349',
#  '69576',
#  '99011',
#  '00117',
#  '87771',
#  '28402',
#  '14088',
#  '00298',
#  '76459',
# ...

# %%
drop_data['user'].replace({'3451100150251':'ไม่ระบุ',
                            '3451100324713':'ไม่ระบุ',
                            '3450500541443':'ไม่ระบุ',
                            '3451100141252':'ไม่ระบุ',
                            '3451100324624':'ไม่ระบุ',
                            '3459900286317':'ไม่ระบุ',
                            '5450100026807':'ไม่ระบุ',
                            '7140':'ไม่ระบุ',
                            '3450101229373':'ไม่ระบุ',
                            '3450101556129':'ไม่ระบุ',
                            '3450100836420':'ไม่ระบุ',
                            '3451100146637':'ไม่ระบุ',
                            '17536\n\n17536':'ไม่ระบุ',
                            '5451100055352':'ไม่ระบุ',
                            '7197':'ไม่ระบุ',
                            '3450100940367':'ไม่ระบุ',
                            '11111111':'ไม่ระบุ',
                            '  67241\n':'67241',
                            '3450101325119':'ไม่ระบุ',
                            'ttohn':'ไม่ระบุ',
                            '45-161':'45161'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
set(drop_data['user'])
# Out:
# {'92042',
#  '19903',
#  '50349',
#  '00131',
#  '75921',
#  '48768',
#  '00266',
#  '19364',
#  '73233',
#  '23675',
#  '46627',
#  '00253',
#  '96699',
#  '18873',
#  '78257',
#  '00001',
#  '52013',
#  '46948',
#  '27604',
#  '71112',
#  '38614',
#  '17415',
#  '71970',
#  '00021',
#  '45783',
#  '53356',
#  '43868',
#  '21860',
#  '02639',
#  '81065',
#  '55300',
#  '72988',
#  '70610',
#  '58271',
#  '84375',
#  '75771',
#  '19201',
#  '03080',
#  '5600190011969',
#  '00206',
#  '19578',
#  '66261',
#  '74369',
#  '98126',
#  '58845',
#  '24563',
#  '00017',
#  '3460500500020',
#  '61320',
#  '18890',
#  '00267',
#  '70948',
#  '70940',
#  '49863',
#  '34988',
#  '00183',
#  '47567',
#  '05961',
#  '48514',
#  '78731',
#  '28961',
#  '00074',
#  '55365',
#  '24179',
#  '00150',
#  '29159',
#  '48298',
#  '77576',
#  '12966',
#  '35605',
#  '56845',
#  '54599',
#  '00036',
#  '96349',
#  '69576',
#  '99011',
#  '00117',
#  '87771',
#  '28402',
#  '14088',
#  '00298',
#  '76459',
# ...

# %%
type('RowKey')
# Out:
# str

# %%
drop_data['date'] = pd.to_datetime(drop_data['date'],format="%Y/%m/%d") # เปลี่ยน format ของข้อมูลวันที่ให้อยู่ในรูปแบบเดียวกัน
drop_data[['date']]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             date
# 0     2022-03-24
# 1     2022-02-23
# 2     2022-02-23
# 3     2022-02-25
# 4     2022-03-23
# ...          ...
# 38562 2022-02-23
# 38565 2022-02-23
# 38566 2022-02-23
# 38569 2022-03-24
# 38570 2022-03-31
#
# [38284 rows x 1 columns]

# %%
type('Phone')
# Out:
# str

# %%
type('urine')
# Out:
# str

# %%
from datetime import datetime

# %%
from datetime import timedelta

# %%
drop_data['time'] = pd.to_timedelta(drop_data['time'],format = "%H:%M:%S") # เปลี่ยน format ของข้อมูลวันที่ให้อยู่ในรูปแบบเดียวกัน
drop_data[['time']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-152-467b4d1f5a2f> in <module>()
# ----> 1 drop_data['time'] = pd.to_timedelta(drop_data['time'],format = "%H:%M:%S") # เปลี่ยน format ของข้อมูลวันที่ให้อยู่ในรูปแบบเดียวกัน
#       2 drop_data[['time']]
#
# TypeError: to_timedelta() got an unexpected keyword argument 'format'

# %%
drop_data
# Out:
#         user                                RowKey       date  \
# 0      85879                        shmpdrmtgc.png 2022-03-24
# 1      45161  D2CABB8C-533B-450A-AFA6-B693749CC1C6 2022-02-23
# 2      45161  57A5F06C-C840-49EA-9514-A30D3C897CC8 2022-02-23
# 3      27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1 2022-02-25
# 4      06223                        kfpwuaqldj.png 2022-03-23
# ...      ...                                   ...        ...
# 38562  76331                        pvpiawlexb.png 2022-02-23
# 38565  68317                        rtutxrlbam.png 2022-02-23
# 38566  68317                        dmuragqwza.png 2022-02-23
# 38569  68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663 2022-03-24
# 38570  99771  E04D3D60-B916-40A1-AE77-91CCD89DD084 2022-03-31
#
#                    phone   site      time            urine ov PartitionKey  \
# 0           OPPO CPH2293  05194  13:08:39          มีตะกอน  0         0000
# ...

# %%
set(drop_data['ov'])
# Out:
# {'0',
#  '1',
#  '2',
#  '3',
#  '4',
#  'ติดเชื้อ +2 ',
#  'มีตะกอน',
#  'มีเม็ดเลือดแดง',
#  'สีฟ้า หรือน้ำเงิน',
#  'ใสเป็นน้ำเปล่า'}

# %%
drop_data['ov'].replace({'ติดเชื้อ +2 ':'ไม่ระบุ',
                            'มีตะกอน':'ไม่ระบุ',
                            'มีเม็ดเลือดแดง':'ไม่ระบุ',
                            'สีฟ้า หรือน้ำเงิน':'ไม่ระบุ',
                            'ใสเป็นน้ำเปล่า':'ไม่ระบุ',}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
set(drop_data['ov'])
# Out:
# {'0', '1', '2', '3', '4', 'ไม่ระบุ'}

# %%
set(drop_data['PartitionKey'])
# Out:
# {'05994',
#  '00632',
#  '04626',
#  '01437',
#  '20044',
#  '02624',
#  '02919',
#  '01261',
#  '02763',
#  '03362',
#  '02730',
#  '01948',
#  '01439',
#  '03552',
#  '00131',
#  '01064',
#  '00779',
#  '01926',
#  '09040',
#  '04014',
#  '00266',
#  '01712',
#  '03932',
#  '01232',
#  '00253',
#  '08914',
#  '00332',
#  '00592',
#  '00546',
#  '01920',
#  '00001',
#  '05223',
#  '01583',
#  '02672',
#  '03383',
#  '03472',
#  '04753',
#  '02686',
#  '00021',
#  '01172',
#  '01362',
#  '03980',
#  '00458',
#  '05259',
#  '05342',
#  '04680',
#  '02752',
#  '00567',
#  '05831',
#  '01696',
#  '02997',
#  '02484',
#  '02639',
#  '03311',
#  '01047',
#  '03378',
#  '01322',
#  '218',
#  '02749',
#  '01603',
#  '00573',
#  '05209',
#  '00860',
#  '02580',
#  '01716',
#  '02370',
#  '01106',
#  '04736',
#  '02989',
#  '00901',
#  '03112',
#  '01961',
#  '00206',
#  '01812',
#  '01355',
#  '04137',
#  '00661',
#  '05280',
#  '00710',
#  '01061',
#  '01128',
#  '01629',
#  '01849',
# ...

# %%
drop_data['PartitionKey'].replace({'218':'ไม่ระบุ',
                            '16':'ไม่ระบุ',
                            '124':'ไม่ระบุ',
                            '179':'ไม่ระบุ',
                            '1881':'ไม่ระบุ',
                            '00083\u200b':'ไม่ระบุ',
                            '48':'ไม่ระบุ',
                            '7140':'ไม่ระบุ',
                            '000167':'ไม่ระบุ',
                            '0-1528':'ไม่ระบุ',
                            '0030':'ไม่ระบุ',
                            '002.5':'ไม่ระบุ',
                            '0034':'ไม่ระบุ',
                            '0012':'ไม่ระบุ',
                            '7197':'ไม่ระบุ',
                            '89':'ไม่ระบุ',
                            '196':'ไม่ระบุ',
                            '153':'67241',
                            '134':'ไม่ระบุ',
                            '0014':'ไม่ระบุ',
                            '0018':'ไม่ระบุ',
                            '112':'ไม่ระบุ',
                            '241':'ไม่ระบุ',}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
set(drop_data['PartitionKey'])
# Out:
# {'05994',
#  '00632',
#  '04626',
#  '01437',
#  '20044',
#  '02624',
#  '02919',
#  '01261',
#  '02763',
#  '03362',
#  '02730',
#  '01948',
#  '01439',
#  '03552',
#  '00131',
#  '01064',
#  '00779',
#  '01926',
#  '09040',
#  '04014',
#  '00266',
#  '01712',
#  '03932',
#  '01232',
#  '00253',
#  '08914',
#  '00332',
#  '00592',
#  '00546',
#  '01920',
#  '00001',
#  '05223',
#  '01583',
#  '02672',
#  '03383',
#  '03472',
#  '04753',
#  '02686',
#  '00021',
#  '01172',
#  '01362',
#  '03980',
#  '00458',
#  '05259',
#  '05342',
#  '04680',
#  '02752',
#  '00567',
#  '05831',
#  '01696',
#  '02997',
#  '02484',
#  '02639',
#  '03311',
#  '01047',
#  '03378',
#  '01322',
#  '02749',
#  '01603',
#  '00573',
#  '05209',
#  '00860',
#  '02580',
#  '01716',
#  '02370',
#  '01106',
#  '04736',
#  '02989',
#  '00901',
#  '03112',
#  '01961',
#  '00206',
#  '01812',
#  '01355',
#  '04137',
#  '00661',
#  '05280',
#  '00710',
#  '01061',
#  '01128',
#  '01629',
#  '01849',
#  '00017',
# ...
